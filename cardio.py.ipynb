# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_cardio = pd.read_csv("cardio_train.csv", sep=",", index_col=0)

df_cardio
# Out:
# Empty DataFrame
# Columns: []
# ...
